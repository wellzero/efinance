# %%
import sys
sys.path.append(r'../')
sys.path.append(r'./')

import efinance as ef

datacenter_xq = ef.stock.fund_xq_getter()
#
# Out:
# getting cookies....
# Setting up Chrome driver...
# Chrome driver setup successful.
# Navigating to https://danjuanfunds.com/...
# 雪球基金 - 与聪明的基民一同发掘投资机会
# Getting cookies...
# Navigating to https://danjuanfunds.com/...
# 雪球基金 - 与聪明的基民一同发掘投资机会
# ...

# %%
# 

data, data_json = datacenter_xq.xq_get_index_overall()
print(data)
# Out:
#         id index_code  name ttype        pe      pb  pe_percentile  \
# 0   497097   SZ399393  国证地产     3    0.0000  0.8835         0.0000
# 1   497069   SZ399812  养老产业     3   12.2939  2.0303         0.0012
# 2   497064   SZ399997  中证白酒     3   19.7396  4.8686         0.1372
# 3   497106  CSIH30094  消费红利     2   20.0014  4.1919         0.1036
# 4   497114   SH000932  主要消费     3   20.0809  4.1077         0.0528
# ..     ...        ...   ...   ...       ...     ...            ...
# 58  497093  CSI931087  科技龙头     3   47.8013  5.6062         0.7525
# 59  497101  CSI930652  中证电子     3   56.2507  5.2564         0.9188
# 60  497072   SH000993  全指信息     3   63.9480  5.1969         0.7324
# 61  497066   SZ399967  中证军工     3   99.2716  3.4253         0.7756
# 62  497104   SH000688  科创50     1  149.7136  5.8737         0.9547
#
#     pb_percentile     roe   yeild  ...  bond_yeild       begin_at  \
# 0          0.2064  0.0000  0.0114  ...        0.05  1439827200000
# ...

# %%
symbol='SP500'
day='all'
df = datacenter_xq.get_data_chrome(symbol, day = day)

print(df.tail(10))
# Out:
#                         pe     roe      pb
# symbol date
# SP500  2025-09-29  29.4934  0.1858  5.4798
#        2025-10-09  29.7581  0.1858  5.5302
#        2025-10-14  29.3248  0.1863  5.4644
#        2025-10-20  29.6441  0.1866  5.5309
#        2025-10-27  29.7445  0.1892  5.6262
#        2025-11-03  29.2561  0.1892  5.5351
#        2025-11-10  29.1540  0.1883  5.4903
#        2025-11-17  28.4491  0.1885  5.3619
#        2025-11-24  28.6161  0.1891  5.4110
#        2025-11-28  29.0940  0.1890  5.4975
