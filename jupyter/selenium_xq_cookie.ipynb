# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

import os
os.environ.pop('HTTP_PROXY', None)
os.environ.pop('HTTPS_PROXY', None)
os.environ.pop('http_proxy', None)
os.environ.pop('https_proxy', None)

# Set up the Chrome driver

# Set up the Chrome driver
options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument("--disable-gpu")

# Set binary location to Chrome executable
options.binary_location = '/opt/google/chrome/chrome'  # Adjust if the file is named differently (e.g., google-chrome)

print("Setting up Chrome driver...")
try:
    # Use specific chromedriver path
    service = Service('/opt/chromedriver/chromedriver')
    driver = webdriver.Chrome(service=service, options=options)
    print("Chrome driver setup successful.")
except Exception as e:
    print(f"Error setting up driver: {e}")
    exit()
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Navigate to the website
print("Navigating to xueqiu.com")
driver.get("https://xueqiu.com/")

# Print the page title
print(driver.title)

# Get the page source
page_source = driver.page_source

# Get cookies
cookies = driver.get_cookies()
print("Cookies:", cookies)
print("Cookies:", cookies)
cookie_str = str()
for cookie in cookies:
      cookie_str += cookie['name']
      cookie_str +='='
      cookie_str += cookie['value']
      cookie_str +='; '

# Close the browser
# print(cookie_str)
driver.close()
# Out:
# Setting up Chrome driver...
# Chrome driver setup successful.
# Navigating to xueqiu.com
# 雪球 - 聪明的投资者都在这里
# Cookies: [{'domain': '.xueqiu.com', 'httpOnly': False, 'name': 'HMACCOUNT', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': 'EE12BC2D3255DAA8'}, {'domain': '.xueqiu.com', 'httpOnly': False, 'name': 'Hm_lpvt_1db88642e346389874251b5a1eded6e3', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '1758203548'}, {'domain': '.xueqiu.com', 'expiry': 1789739548, 'httpOnly': False, 'name': 'Hm_lvt_1db88642e346389874251b5a1eded6e3', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '1758203548'}, {'domain': '.xueqiu.com', 'expiry': 1758205347, 'httpOnly': False, 'name': 'ssxmod_itna2', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '1-YqUx0DcD20YQqY5i73YexYTx0xYK7QmNDXDUqAjtGg0DFqApxDHCmaC0KaYi9KQClGDD8fAkBYDi=R0YIts9jEq1llxe2i_qi3=3TxD'}, {'domain': 'xueqiu.com', 'expiry': 1792763538, 'httpOnly': False, 'name': 'smidV2', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '20250918215218bee18402e70fdc6a03e179c480c4c8d100bc88d96ebd4c210'}, {'domain': 'xueqiu.com', 'expiry': 1758205326, 'httpOnly': True, 'name': 'acw_tc', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '3ccdc14217582041668642690e1a614207fa5c9cd568318df9318f01655db7'}, {'domain': '.xueqiu.com', 'expiry': 1789825926, 'httpOnly': False, 'name': 'cookiesu', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '721758204167072'}, {'domain': '.xueqiu.com', 'expiry': 1789825937, 'httpOnly': False, 'name': 'device_id', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '4c482614672548898c7730beb93d022b'}, {'domain': '.xueqiu.com', 'httpOnly': True, 'name': 'xq_r_token', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': 'ccc05ead3663299c1a536fdb28a66e816436acf8'}, {'domain': 'xueqiu.com', 'expiry': 1792763539, 'httpOnly': False, 'name': '.thumbcache_f24b8bbe5a5934237bbc0eda20c1b6e7', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': 