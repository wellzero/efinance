# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

from pathlib import Path
import requests
import json
import pandas as pd
session = requests.Session()


def get_common_json(url, params, head = "default"):
    
  if (head == "default"):
    json_response = session.get(url,
                                params=params).json()
  else:
    json_response = session.get(url,
                                headers=head,
                                params=params).json()
  return json_response

# %%
# https://api.lbkrs.com/v2/newmarket/global/industry_chart?market=US&index_key=ETF%2FUS%2FSPY&limit=20

# :authority:api.lbkrs.com
# :method:OPTIONS
# :path:/v2/newmarket/global/industry_chart?market=US&index_key=ETF%2FUS%2FSPY&limit=20
# :scheme:https
# Accept:*/*
# Accept-Encoding:gzip, deflate, br, zstd
# Accept-Language:en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7
# Access-Control-Request-Headers:cache-control,uber-trace-id,x-api-key,x-api-signature,x-application-build,x-application-version,x-bundle-id,x-device-id,x-engine-version,x-platform,x-request-id,x-timestamp
# Access-Control-Request-Method:GET
# Origin:https://longportapp.com
# Priority:u=1, i
# Referer:https://longportapp.com/
# Sec-Fetch-Dest:empty
# Sec-Fetch-Mode:cors
# Sec-Fetch-Site:cross-site
# User-Agent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36

url = 'https://api.lbkrs.com/v2/newmarket/global/industry_chart'

headers = {
            # ':authority': 'api.lbkrs.com',
            # ':method': 'OPTIONS',
            # ':path': '/v2/newmarket/global/industry_chart?market=US&index_key=ETF%2FUS%2FSPY&limit=20',
            # ':scheme': 'https',
            'Accept':'*/*',
            'Accept-Encoding':'gzip, deflate, br, zstd',
            'Accept-Language':'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7',
            'Access-Control-Request-Headers':'cache-control,uber-trace-id,x-api-key,x-api-signature,x-application-build,x-application-version,x-bundle-id,x-device-id,x-engine-version,x-platform,x-request-id,x-timestamp',
            'Cookie':'x-device-id=0110bb9594fe7b7eaf12183fa6fa472407edba901bcfcb5d64edad0cb4f690c2; x-device-id.sig=9WETMZh1jKedTJfK16gQyb_lQ7JCf2TYbVU8SgcZAwk; acw_tc=3ccdc14c17199254883088209e4f487b66a5fc174c6d605b55f5c53321eef8',
            'Access-Control-Request-Method':'GET',
            'Origin': 'https://longportapp.com/',
            'Priority':'u=1, i',
            'Referer': 'https://longportapp.com/',
            'Sec-Fetch-Dest':'empty',
            'Sec-Fetch-Mode':'cors',
            'Sec-Fetch-Site':'cross-site',
            'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
}
params = [
        ('market', 'US'),
        ('index_key', 'ETF/US/SPY'),
        ('limit', '20')
]



# Accept:*/*
# Accept-Encoding:gzip, deflate, br, zstd
# Accept-Language:en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7
# Access-Control-Request-Headers:cache-control,uber-trace-id,x-api-key,x-api-signature,x-application-build,x-application-version,x-bundle-id,x-device-id,x-engine-version,x-platform,x-request-id,x-timestamp
# Access-Control-Request-Method:GET
# Connection:keep-alive
# Host:api.lbkrs.com
# Origin:https://longportapp.com
# Referer:https://longportapp.com/
# Sec-Fetch-Dest:empty
# Sec-Fetch-Mode:cors
# Sec-Fetch-Site:cross-site
# User-Agent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36


# url = 'https://api.lbkrs.com/market/concept_stocks'
# headers = {

#             'Accept':'*/*',
#             'Accept-Encoding':'gzip, deflate, br, zstd',
#             'Accept-Language':'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7',
#             'Access-Control-Request-Headers':'cache-control,uber-trace-id,x-api-key,x-api-signature,x-application-build,x-application-version,x-bundle-id,x-device-id,x-engine-version,x-platform,x-request-id,x-timestamp',
#             'Access-Control-Request-Method':'GET',
#             'Connection':'keep-alive',
#             'Host':'api.lbkrs.com',
#             'Cookie':'x-device-id=0110bb9594fe7b7eaf12183fa6fa472407edba901bcfcb5d64edad0cb4f690c2; x-device-id.sig=9WETMZh1jKedTJfK16gQyb_lQ7JCf2TYbVU8SgcZAwk; acw_tc=3ccdc14c17199254883088209e4f487b66a5fc174c6d605b55f5c53321eef8',
#             'Origin': 'https://longportapp.com/',
#             'Referer': 'https://longportapp.com/',
#             'Sec-Fetch-Dest':'empty',
#             'Sec-Fetch-Mode':'cors',
#             'Sec-Fetch-Site':'cross-site',
#             'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36'
# }



# params = [
# ('concept_index', 'BK/US/IN00388'),
# ('indicator', 1),
# ('limit', 5),
# ('offset', 0),
# ('order', 0),
# ('tab_key', 0),
# ('filter_tag_key', 3),
# ]



# response = get_common_json(url, params, head = headers)
response = get_common_json(url, params, headers)
